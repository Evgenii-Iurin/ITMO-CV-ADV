# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n-pose.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-pose.pt to 'yolo11n-pose.pt'...
# 100%|██████████| 5.97M/5.97M [00:00<00:00, 19.0MB/s]

# %%
results = model.train(data="hand-keypoints.yaml", epochs=100, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.147 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.136 🚀 Python-3.11.12 torch-2.7.0+cu126 CUDA:0 (NVIDIA A100 80GB PCIe, 81038MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=hand-keypoints.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/pose/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/kb/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 4.38MB/s]
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[21, 3]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    804898  ultralytics.nn.modules.head.Pose             [1, [21, 3], [64, 128, 256]]
# YOLO11n-pose summary: 196 layers, 2,964,066 parameters, 2,964,050 gradients, 7.9 GFLOPs
#
# Transferred 505/541 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 16.8MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 650.7±407.7 MB/s, size: 12.5 KB)
# train: Scanning /home/kb/hands_pose/datasets/hand-keypoints/train/labels... 18776 images, 0 backgrounds, 491 corrupt: 100%|██████████| 18776/18776 [00:17<00:00, 1081.02it/s]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00001070.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0379]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00001796.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0006]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00001800.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0027]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00001801.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0049]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00001886.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0051      1.0038      1.0088      1.0114]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00001887.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0048      1.0062      1.0099      1.0121]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00001888.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [          1      1.0017]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00001994.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0059]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00001998.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0044]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00001999.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.007]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002000.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0083]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0146]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002002.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0178]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002003.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0178]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002143.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0582      1.0216]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002144.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0641      1.0333]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002202.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0041      1.0052       1.008      1.0093      1.0108      1.0112      1.0116]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002451.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0121]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002454.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.023      1.0012]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002545.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0051]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002744.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0159]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002745.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0334]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002746.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0399]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002747.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0453      1.0009]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002749.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0701       1.011]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002751.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0658      1.0113]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002752.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0505]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002754.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0313]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002760.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0266]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002761.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0449]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002991.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0021      1.0099]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00002996.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.007]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0211      1.0371      1.0143      1.0292      1.0036      1.0175      1.0073]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003109.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0766      1.0215]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003111.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0615      1.0047]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003114.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0173]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003162.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0111      1.0368]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003164.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0071      1.0047      1.0238      1.0125      1.0397        1.01      1.0396      1.0152]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003372.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.003      1.0101]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003385.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0125       1.027      1.0279      1.0451      1.0597]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003387.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0005      1.0227      1.0413      1.0243      1.0437      1.0603]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003388.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0187      1.0366      1.0213       1.039      1.0546]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003390.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0208      1.0405      1.0225      1.0423      1.0603]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003391.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0067      1.0217       1.012      1.0306      1.0467]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003392.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.016      1.0059      1.0274      1.0465]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003393.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.006      1.0067      1.0219]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003434.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0763      1.0129]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003438.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0473]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003439.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0106]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003440.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0347]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003442.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.018]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003444.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0436      1.0107]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003491.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0061]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003492.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.005]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003592.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0092      1.0162]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003593.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0013      1.0155      1.0172      1.0174]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003653.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.016]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003654.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0179]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003737.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0062      1.0065]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003738.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0084      1.0016      1.0135      1.0192      1.0068]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003739.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0047      1.0169      1.0028      1.0193      1.0201      1.0166]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003852.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0196      1.0118      1.0018      1.0866      1.1344      1.1761]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003853.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.05      1.0787      1.0921      1.0357      1.1215       1.152      1.1742]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00003854.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0046      1.0566      1.0449      1.1035      1.1434      1.0066       1.097      1.1416      1.1766]
# train: /home/kb/hands_pose/datasets/hand-keypoints/train/images/IMG_00
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      11/100         3G     0.7998      4.411     0.3621     0.5377      1.175         29        640: 100%|██████████| 1143/1143 [02:31<00:00,  7.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 244/244 [01:16<00:00,  3.18it/s]
#                    all       7808       7808      0.962      0.963      0.988       0.85      0.802      0.704      0.701      0.493
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      3.02G     0.7869      4.303     0.3562     0.5275      1.169         31        640: 100%|██████████| 1143/1143 [02:30<00:00,  7.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 244/244 [01:18<00:00,  3.11it/s]
#                    all       7808       7808      0.964      0.959      0.988      0.853      0.823      0.709      0.729      0.535
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      3.03G     0.7833      4.247     0.3494     0.5217      1.168         28        640: 100%|██████████| 1143/1143 [02:25<00:00,  7.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 244/244 [01:14<00:00,  3.28it/s]
#                    all       7808       7808      0.963      0.962      0.988      0.857      0.838      0.732      0.766      0.569
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      3.04G     0.7715      4.163     0.3428     0.5089      1.159         28        640: 100%|██████████| 1143/1143 [02:28<00:00,  7.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 244/244 [01:15<00:00,  3.22it/s]
#                    all       7808       7808      0.954      0.954      0.986       0.85      0.815       0.71      0.717      0.518
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      3.05G     0.7648      4.086     0.3383     0.5079       1.16         25        640: 100%|██████████| 1143/1143 [02:27<00:00,  7.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 244/244 [01:18<00:00,  3.12it/s]
#                    all       7808       7808      0.959       0.97      0.988      0.861      0.823      0.762      0.781      0.597
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      3.06G     0.7519      4.021     0.3337     0.4935      1.147         34        640: 100%|██████████| 1143/1143 [02:29<00:00,  7.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 244/244 [01:17<00:00,  3.14it/s]
#                    all       7808       7808      0.968      0.962      0.989      0.867      0.836      0.765      0.776      0.588
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      3.07G     0.7525      3.986     0.3303     0.4936      1.149         35        640: 100%|██████████| 1143/1143 [02:29<00:00,  7.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 244/244 [01:16<00:00,  3.19it/s]
#                    all       7808       7808      0.965      0.972      0.989      0.869      0.808      0.762      0.748      0.566
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      3.08G     0.7472      3.929     0.3261     0.4904      1.143         34        640: 100%|██████████| 1143/1143 [02:28<00:00,  7.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 244/244 [01:12<00:00,  3.35it/s]
#                    all       7808       7808      0.966      0.969      0.989       0.87      0.813      0.755      0.765      0.598
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      3.09G     0.7419      3.841     0.3207     0.4843      1.141         23        640: 100%|██████████| 1143/1143 [02:29<00:00,  7.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95):  68%|██████▊   | 165/244 [00:51<00:24,  3.23it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 results = model.train(data="hand-keypoints.yaml", epochs=100, imgsz=640)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/ultralytics/engine/model.py:793, in Model.train(self, trainer, **kwargs)
#     790     self.model = self.trainer.model
#     792 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 793 self.trainer.train()
#     794 # Update model and cfg after training
#     795 if RANK in {-1, 0}:
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/ultralytics/engine/trainer.py:211, in BaseTrainer.train(self)
#     208         ddp_cleanup(self, str(file))
#     210 else:
# --> 211     self._do_train(world_size)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/ultralytics/engine/trainer.py:443, in BaseTrainer._do_train(self, world_size)
#     441 # Validation
#     442 if self.args.val or final_epoch or self.stopper.possible_stop or self.stop:
# --> 443     self.metrics, self.fitness = self.validate()
#     444 self.save_metrics(metrics={**self.label_loss_items(self.tloss), **self.metrics, **self.lr})
#     445 self.stop |= self.stopper(epoch + 1, self.fitness) or final_epoch
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/ultralytics/engine/trainer.py:639, in BaseTrainer.validate(self)
#     632 def validate(self):
#     633     """
#     634     Run validation on test set using self.validator.
#     635
#     636     Returns:
#     637         (tuple): A tuple containing metrics dictionary and fitness score.
#     638     """
# --> 639     metrics = self.validator(self)
#     640     fitness = metrics.pop("fitness", -self.loss.detach().cpu().numpy())  # use loss as fitness measure if not found
#     641     if not self.best_fitness or self.best_fitness < fitness:
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/ultralytics/engine/validator.py:225, in BaseValidator.__call__(self, trainer, model)
#     222 with dt[3]:
#     223     preds = self.postprocess(preds)
# --> 225 self.update_metrics(preds, batch)
#     226 if self.args.plots and batch_i < 3:
#     227     self.plot_val_samples(batch, batch_i)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/ultralytics/models/yolo/pose/val.py:207, in PoseValidator.update_metrics(self, preds, batch)
#     205 # Evaluate
#     206 if nl:
# --> 207     stat["tp"] = self._process_batch(predn, bbox, cls)
#     208     stat["tp_p"] = self._process_batch(predn, bbox, cls, pred_kpts, pbatch["kpts"])
#     209 if self.args.plots:
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/ultralytics/models/yolo/pose/val.py:256, in PoseValidator._process_batch(self, detections, gt_bboxes, gt_cls, pred_kpts, gt_kpts)
#     253 else:  # boxes
#     254     iou = box_iou(gt_bboxes, detections[:, :4])
# --> 256 return self.match_predictions(detections[:, 5], gt_cls, iou)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/ultralytics/engine/validator.py:276, in BaseValidator.match_predictions(self, pred_classes, true_classes, iou, use_scipy)
#     274 correct_class = true_classes[:, None] == pred_classes
#     275 iou = iou * correct_class  # zero out the wrong classes
# --> 276 iou = iou.cpu().numpy()
#     277 for i, threshold in enumerate(self.iouv.cpu().tolist()):
#     278     if use_scipy:
#     279         # WARNING: known issue that reduces mAP in https://github.com/ultralytics/ultralytics/pull/4708
#
# KeyboardInterrupt:

# %%
trained_model = YOLO("runs/pose/train2/weights/last.pt")

# %%
results = trained_model.predict("datasets/hand-keypoints/val/images/IMG_00000003.jpg")
# Out:
# image 1/1 /home/kb/hands_pose/datasets/hand-keypoints/val/images/IMG_00000003.jpg: 640x640 1 hand, 46.7ms
# Speed: 11.3ms preprocess, 46.7ms inference, 11.9ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# ## Custom model

# %%
import os
import torch
from torch.utils.data import Dataset
from PIL import Image
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %% [markdown]
# ### Dataset

# %% [markdown]
# #### Points and bboxes

# %%
class HandKeypointDetectionDataset(Dataset):
    def __init__(self, image_dir, label_dir, image_size=256):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.image_files = sorted([f for f in os.listdir(image_dir) if f.endswith(('.jpg', '.png'))])
        self.image_size = image_size

        self.transform = transforms.Compose([
            transforms.Resize((image_size, image_size)),
            transforms.ToTensor(),
        ])

        # Pre-filter valid samples
        self.valid_image_files = self._filter_valid_samples()

    def _filter_valid_samples(self):
        valid_files = []
        for image_name in self.image_files:
            label_path = os.path.join(self.label_dir, image_name.replace('.jpg', '.txt').replace('.png', '.txt'))
            try:
                with open(label_path, 'r') as f:
                    line = f.readline().strip().split()
                    line = list(map(float, line))
                    keypoints = torch.tensor(line[5:], dtype=torch.float32).view(21, 3)
                    if torch.all((keypoints[:, 0] >= 0) & (keypoints[:, 0] <= 1) &
                                 (keypoints[:, 1] >= 0) & (keypoints[:, 1] <= 1)):
                        valid_files.append(image_name)
            except:
                continue  # skip unreadable or malformed files
        return valid_files

    def __len__(self):
        return len(self.valid_image_files)

    def __getitem__(self, idx):
        image_name = self.valid_image_files[idx]
        image_path = os.path.join(self.image_dir, image_name)
        label_path = os.path.join(self.label_dir, image_name.replace('.jpg', '.txt').replace('.png', '.txt'))

        image = Image.open(image_path).convert("RGB")
        image = self.transform(image)

        with open(label_path, 'r') as f:
            line = f.readline().strip().split()
            line = list(map(float, line))

        bbox = torch.tensor(line[1:5], dtype=torch.float32)  # cx, cy, w, h
        keypoints = torch.tensor(line[5:], dtype=torch.float32).view(21, 3)

        target = {
            "bbox": bbox,
            "keypoints": keypoints,
            "image_id": image_name
        }

        return image, target

# %% [markdown]
# #### Heatmaps

# %%
# Heatmaps
import os
import torch
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image
import numpy as np

class HandKeypointDetectionDataset(Dataset):
    def __init__(self, image_dir, label_dir, image_size=224, heatmap_size=56, sigma=1.5):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.image_files = sorted([f for f in os.listdir(image_dir) if f.endswith(('.jpg', '.png'))])
        self.image_size = image_size
        self.heatmap_size = heatmap_size
        self.sigma = sigma

        self.transform = transforms.Compose([
            transforms.Resize((image_size, image_size)),
            transforms.ToTensor(),
        ])

        self.valid_image_files = self._filter_valid_samples()

    def _filter_valid_samples(self):
        valid_files = []
        for image_name in self.image_files:
            label_path = os.path.join(self.label_dir, image_name.replace('.jpg', '.txt').replace('.png', '.txt'))
            try:
                with open(label_path, 'r') as f:
                    line = list(map(float, f.readline().strip().split()))
                    keypoints = torch.tensor(line[5:], dtype=torch.float32).view(21, 3)
                    if torch.all((keypoints[:, 0] >= 0) & (keypoints[:, 0] <= 1) &
                                 (keypoints[:, 1] >= 0) & (keypoints[:, 1] <= 1)):
                        valid_files.append(image_name)
            except:
                continue
        return valid_files

    def __len__(self):
        return len(self.valid_image_files)

    def __getitem__(self, idx):
        image_name = self.valid_image_files[idx]
        image_path = os.path.join(self.image_dir, image_name)
        label_path = os.path.join(self.label_dir, image_name.replace('.jpg', '.txt').replace('.png', '.txt'))

        image = Image.open(image_path).convert("RGB")
        image = self.transform(image)

        with open(label_path, 'r') as f:
            line = list(map(float, f.readline().strip().split()))

        keypoints = torch.tensor(line[5:], dtype=torch.float32).view(21, 3)

        # Generate heatmaps
        heatmaps = self._generate_heatmaps(keypoints)

        target = {
            "heatmaps": heatmaps,   # shape: [21, heatmap_size, heatmap_size]
            "image_id": image_name,
        }

        return image, target

    def _generate_heatmaps(self, keypoints):
        heatmaps = np.zeros((21, self.heatmap_size, self.heatmap_size), dtype=np.float32)

        for i, (x, y, v) in enumerate(keypoints):
            if v < 0.5:  # visibility threshold
                continue

            x_hm = int(x * self.heatmap_size)
            y_hm = int(y * self.heatmap_size)

            if 0 <= x_hm < self.heatmap_size and 0 <= y_hm < self.heatmap_size:
                heatmaps[i] = self._draw_gaussian(heatmaps[i], (x_hm, y_hm), self.sigma)

        return torch.tensor(heatmaps)

    def _draw_gaussian(self, heatmap, center, sigma):
        mu_x, mu_y = center

        x = np.arange(0, self.heatmap_size, 1, float)
        y = np.arange(0, self.heatmap_size, 1, float)[:, np.newaxis]
        g = np.exp(- ((x - mu_x) ** 2 + (y - mu_y) ** 2) / (2 * sigma ** 2))

        heatmap = np.maximum(heatmap, g)
        return heatmap

# %%
# Paths
train_image_dir = "datasets/hand-keypoints/train/images"
train_label_dir = "datasets/hand-keypoints/train/labels"
val_image_dir = "datasets/hand-keypoints/val/images"
val_label_dir = "datasets/hand-keypoints/val/labels"

# Create dataset and dataloader
train_dataset = HandKeypointDetectionDataset(train_image_dir, train_label_dir, image_size=224)
val_dataset = HandKeypointDetectionDataset(val_image_dir, val_label_dir, image_size=224)

train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

# %%
for images, targets in train_loader:
    print(images.shape)             # [B, 3, 256, 256]
    # print(targets["bbox"].shape)    # [B, 4]
    print(targets["heatmaps"].shape)  # [B, 21, 3]
    break

for images, targets in val_loader:
    print(images.shape)             # [B, 3, 256, 256]
    # print(targets["bbox"].shape)    # [B, 4]
    print(targets["heatmaps"].shape)  # [B, 21, 3]
    break
# Out:
# torch.Size([32, 3, 224, 224])
# torch.Size([32, 21, 56, 56])
# torch.Size([32, 3, 224, 224])
# torch.Size([32, 21, 56, 56])

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_heatmaps(dataset, num_samples=3, figsize=(15, 10)):
    """Visualize original images with heatmap overlays"""
    plt.figure(figsize=figsize)
    
    for i in range(num_samples):
        # Get a sample from the dataset
        image_tensor, target = dataset[i]
        image = image_tensor.permute(1, 2, 0).numpy()  # CHW to HWC
        heatmaps = target["heatmaps"].numpy()
        
        # Create subplots
        plt.subplot(num_samples, 2, 2*i+1)
        plt.imshow(image)
        plt.title(f"Original: {target['image_id']}")
        plt.axis('off')
        
        # Overlay heatmaps on original image
        plt.subplot(num_samples, 2, 2*i+2)
        plt.imshow(image, alpha=0.7)
        
        # Combine all keypoint heatmaps (max across channels)
        combined_heatmap = np.max(heatmaps, axis=0)
        plt.imshow(combined_heatmap, cmap='jet', alpha=0.5)
        plt.title("Heatmap Overlay")
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

def visualize_individual_heatmaps(dataset, sample_idx=0):
    """Visualize all 21 heatmaps separately"""
    image_tensor, target = dataset[sample_idx]
    image = image_tensor.permute(1, 2, 0).numpy()
    heatmaps = target["heatmaps"].numpy()
    
    plt.figure(figsize=(20, 15))
    plt.subplot(5, 5, 1)
    plt.imshow(image)
    plt.title("Original Image")
    plt.axis('off')
    
    for i in range(21):
        plt.subplot(5, 5, i+2)
        plt.imshow(heatmaps[i], cmap='jet')
        plt.title(f"Keypoint {i}")
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Usage example:
    # Initialize your dataset
dataset = HandKeypointDetectionDataset(
        image_dir="datasets/hand-keypoints/train/images",
        label_dir="datasets/hand-keypoints/train/labels",
        image_size=224,
        heatmap_size=64,
        sigma=1.5
    )
    
    # Visualize combined heatmaps
visualize_heatmaps(dataset, num_samples=3)
    
    # Visualize individual heatmaps for first sample
visualize_individual_heatmaps(dataset, sample_idx=0)

# %% [markdown]
# ### Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# #### Points and bboxes

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights


class HandKeypointModel(nn.Module):
    def __init__(self, architecture='simple', pretrained=True):
        super(HandKeypointModel, self).__init__()
        self.architecture = architecture.lower()

        if self.architecture == 'simple':
            self.backbone = nn.Sequential(
                nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
                nn.BatchNorm2d(32),
                nn.ReLU(),
                nn.MaxPool2d(2),

                nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
                nn.BatchNorm2d(64),
                nn.ReLU(),
                nn.MaxPool2d(2),

                nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
                nn.BatchNorm2d(128),
                nn.ReLU(),
                nn.MaxPool2d(2),

                nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
                nn.BatchNorm2d(256),
                nn.ReLU(),
                nn.AdaptiveAvgPool2d((1, 1))
            )
            self.feature_dim = 256

        elif self.architecture == 'resnet18':
            base = models.resnet18(pretrained=pretrained)
            layers = list(base.children())[:-1]  # remove fc layer
            self.backbone = nn.Sequential(*layers)  # output: [B, 512, 1, 1]
            self.feature_dim = 512

        elif self.architecture == 'efficientnet_b0':
            base = efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT if pretrained else None)
            self.backbone = base.features
            self.pool = nn.AdaptiveAvgPool2d((1, 1))
            self.feature_dim = 1280
        else:
            raise ValueError(f"Unknown architecture: {self.architecture}")

        # Общая голова
        self.head = nn.Sequential(
            nn.Flatten(),
            nn.Linear(self.feature_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 67)  # bbox(4) + keypoints(21*2) + visibility(21)
        )

    def forward(self, x):
        x = self.backbone(x)
        if self.architecture == 'efficientnet_b0':
            x = self.pool(x)
        x = self.head(x)

        # Разбиваем выход
        bbox = x[:, :4]
        keypoints = x[:, 4:46].view(-1, 21, 2)
        visibility = x[:, 46:].view(-1, 21)

        return {
            "bbox": bbox,
            "keypoints": keypoints,
            "visibility": visibility
        }

# %% [markdown]
# #### Heatmaps-based

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights


class HeatmapHandKeypointModel(nn.Module):
    def __init__(self, num_keypoints=21, heatmap_size=64, architecture='simple', pretrained=True):
        super(HeatmapHandKeypointModel, self).__init__()
        self.num_keypoints = num_keypoints
        self.heatmap_size = heatmap_size
        self.architecture = architecture.lower()

        if self.architecture == 'simple':
            self.backbone = nn.Sequential(
                nn.Conv2d(3, 32, kernel_size=3, padding=1),
                nn.BatchNorm2d(32),
                nn.ReLU(),
                nn.MaxPool2d(2),

                nn.Conv2d(32, 64, kernel_size=3, padding=1),
                nn.BatchNorm2d(64),
                nn.ReLU(),
                nn.MaxPool2d(2),

                nn.Conv2d(64, 128, kernel_size=3, padding=1),
                nn.BatchNorm2d(128),
                nn.ReLU(),

                nn.Conv2d(128, 256, kernel_size=3, padding=1),
                nn.BatchNorm2d(256),
                nn.ReLU()
            )
            self.backbone_out_channels = 256
            self.need_upsample = False  # already outputs [B, C, 64, 64]

        elif self.architecture == 'resnet18':
            base = models.resnet18(pretrained=pretrained)
            layers = list(base.children())[:-2]  # Keep output: [B, 512, 8, 8]
            self.backbone = nn.Sequential(*layers)
            self.backbone_out_channels = 512
            self.need_upsample = True

        elif self.architecture == 'efficientnet_b0':
            base = efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT if pretrained else None)
            self.backbone = base.features
            self.backbone_out_channels = 1280
            self.need_upsample = True
        else:
            raise ValueError(f"Unknown architecture: {self.architecture}")

        # Head that generates heatmaps
        self.head = nn.Sequential(
            nn.Conv2d(self.backbone_out_channels, num_keypoints, kernel_size=1),
            nn.Sigmoid()  # Optional, for heatmaps in [0,1] range
        )

        # If backbone output is not the same size as heatmap_size, upsample
        if self.need_upsample:
            self.upsample = nn.Upsample(size=(heatmap_size, heatmap_size), mode='bilinear', align_corners=False)
        else:
            self.upsample = nn.Identity()

    def forward(self, x):
        x = self.backbone(x)               # -> [B, C, H, W]
        x = self.head(x)                   # -> [B, num_keypoints, H, W]
        x = self.upsample(x)               # -> [B, num_keypoints, heatmap_size, heatmap_size]
        return x                           # heatmaps

# %% [markdown]
# ### Loss

# %% [markdown]
# #### Points and bboxes

# %%
class HandKeypointLoss(nn.Module):
    def __init__(self, use_visibility_loss=True, lambda_box=1.0, lambda_kpts=10.0, lambda_vis=0.1):
        super().__init__()
        self.use_visibility_loss = use_visibility_loss

        self.box_loss_fn = nn.SmoothL1Loss()
        self.kpt_loss_fn = nn.MSELoss(reduction='none')
        self.vis_loss_fn = nn.BCEWithLogitsLoss()

        self.lambda_box = lambda_box
        self.lambda_kpts = lambda_kpts
        self.lambda_vis = lambda_vis

    def forward(self, preds, targets):
        pred_boxes = preds["bbox"]          # [B, 4]
        pred_keypoints = preds["keypoints"]  # [B, 21, 2]
        pred_visibility = preds["visibility"]  # [B, 21]

        target_boxes = targets["bbox"]        # [B, 4]
        target_keypoints = targets["keypoints"][:, :, :2]  # [B, 21, 2]
        target_vis = targets["keypoints"][:, :, 2]          # [B, 21]

        # --- 1. Bounding box loss ---
        loss_bbox = self.box_loss_fn(pred_boxes, target_boxes)

        # --- 2. Keypoint regression loss ---
        # Only apply to visible keypoints
        vis_mask = (target_vis > 0).unsqueeze(-1)  # [B, 21, 1]
        keypoint_diff = self.kpt_loss_fn(pred_keypoints, target_keypoints)  # [B, 21, 2]
        keypoint_loss = (keypoint_diff * vis_mask).sum() / (vis_mask.sum() + 1e-6)

        # --- 3. Visibility prediction loss ---
        if self.use_visibility_loss:
            loss_vis = self.vis_loss_fn(pred_visibility, target_vis)
        else:
            loss_vis = torch.tensor(0.0, device=pred_boxes.device)

        # --- Final weighted loss ---
        total_loss = (
            self.lambda_box * loss_bbox +
            self.lambda_kpts * keypoint_loss +
            self.lambda_vis * loss_vis
        )

        return total_loss, {
            "bbox_loss": loss_bbox.item(),
            "keypoint_loss": keypoint_loss.item(),
            "visibility_loss": loss_vis.item() if self.use_visibility_loss else 0.0
        }

# %% [markdown]
# #### Heatmaps-based

# %%
class HeatmapKeypointLoss(nn.Module):
    def __init__(self):
        super(HeatmapKeypointLoss, self).__init__()
        self.criterion = nn.MSELoss()

    def forward(self, pred_heatmaps, target_heatmaps):
        """
        Args:
            pred_heatmaps: Tensor of shape [B, 21, H, W]
            target_heatmaps: Tensor of shape [B, 21, H, W]
        """
        loss = self.criterion(pred_heatmaps, target_heatmaps)
        return loss

# %% [markdown]
# ### Inference and vis

# %%
import cv2

# %% [markdown]
# #### Points and bboxes

# %%
def predict_and_draw(model, image_tensor, orig_image, use_visibility=False, threshold=0.5, device="cuda"):
    """
    Args:
        model: trained model
        image_tensor: [1, 3, H, W] normalized and resized
        orig_image: original image (H, W, 3) as loaded by cv2 (BGR)
        threshold: minimum visibility score to draw a keypoint
        device: 'cuda' or 'cpu'
    Returns:
        vis_image: visualization image (RGB format)
    """
    model.eval()
    image_tensor = image_tensor.to(device)
    with torch.no_grad():
        preds = model(image_tensor)
    if not use_visibility:
        threshold=100
        v=0
    
    # Extract predictions
    pred_bbox = preds["bbox"][0].cpu().numpy()          # [4]
    pred_kpts = preds["keypoints"][0].cpu().numpy()     # [21, 2]
    pred_vis = preds["visibility"][0].cpu().numpy()     # [21]

    h, w, _ = orig_image.shape

    # Rescale bbox and keypoints to original image size
    cx, cy, bw, bh = pred_bbox
    cx *= w
    cy *= h
    bw *= w
    bh *= h
    x1 = int(cx - bw / 2)
    y1 = int(cy - bh / 2)
    x2 = int(cx + bw / 2)
    y2 = int(cy + bh / 2)

    # Draw bounding box
    vis_image = orig_image.copy()
    cv2.rectangle(vis_image, (x1, y1), (x2, y2), (0, 255, 0), 2)

    # Draw keypoints
    for i, (x, y) in enumerate(pred_kpts):
        if use_visibility and pred_vis[i] <= threshold:
            continue
            
        px, py = int(x * w), int(y * h)
        cv2.circle(vis_image, (px, py), 1, (0, 0, 255), -1)
        # cv2.putText(vis_image, str(i), (px+2, py-2), cv2.FONT_HERSHEY_SIMPLEX, 0.2, (255,255,255), 1)
    
    # Convert BGR to RGB for matplotlib
    vis_image_rgb = cv2.cvtColor(vis_image, cv2.COLOR_BGR2RGB)
    return vis_image_rgb

# %% [markdown]
# #### Heatmaps

# %%
import torch
import cv2
import numpy as np
import matplotlib.pyplot as plt

def predict_and_draw(model, image_tensor, orig_image, threshold=0.1, device="cuda"):
    """
    Args:
        model: trained model
        image_tensor: [1, 3, H, W] normalized and resized
        orig_image: original image (H, W, 3) as loaded by cv2 (BGR)
        threshold: minimum heatmap peak value to draw a keypoint
        device: 'cuda' or 'cpu'
    Returns:
        vis_image_rgb: visualization image (RGB format)
    """
    model.eval()
    image_tensor = image_tensor.to(device)

    with torch.no_grad():
        pred_heatmaps = model(image_tensor)  # [1, 21, H, W]

    pred_heatmaps = pred_heatmaps.squeeze(0).cpu().numpy()  # [21, H, W]
    h_img, w_img, _ = orig_image.shape
    h_heatmap, w_heatmap = pred_heatmaps.shape[1], pred_heatmaps.shape[2]

    keypoints = []

    for i in range(pred_heatmaps.shape[0]):
        heatmap = pred_heatmaps[i]
        max_val = np.max(heatmap)
        if max_val < threshold:
            keypoints.append(None)
            continue

        y, x = np.unravel_index(np.argmax(heatmap), heatmap.shape)
        # Convert heatmap coords to original image coords
        x = int((x / w_heatmap) * w_img)
        y = int((y / h_heatmap) * h_img)
        keypoints.append((x, y))

    vis_image = orig_image.copy()

    for pt in keypoints:
        if pt is not None:
            cv2.circle(vis_image, pt, 3, (0, 0, 255), -1)

    vis_image_rgb = cv2.cvtColor(vis_image, cv2.COLOR_BGR2RGB)
    return vis_image_rgb

# %% [markdown]
# ### Training

# %%
import torch
from torch.optim import AdamW
from tqdm import tqdm

# %% [markdown]
# #### Points and bboxes

# %% [markdown]
# ##### Resnet-based

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = HandKeypointModel(architecture="resnet18").to(device)
criterion = HandKeypointLoss(use_visibility_loss=False)
optimizer = AdamW(model.parameters(), lr=1e-3)

num_epochs = 15

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for images, targets in tqdm(train_loader, desc=f"Train Epoch {epoch+1}/{num_epochs}"):
        images = images.to(device)
        targets = {k: v for k, v in targets.items()}
        targets['bbox'] = targets['bbox'].to(device)
        targets['keypoints'] = targets['keypoints'].to(device)

        optimizer.zero_grad()
        preds = model(images)

        loss, loss_dict = criterion(preds, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(train_loader)

    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for images, targets in val_loader:
            images = images.to(device)
            targets = {k: v for k, v in targets.items()}
            targets['bbox'] = targets['bbox'].to(device)
            targets['keypoints'] = targets['keypoints'].to(device)

            preds = model(images)
            loss, _ = criterion(preds, targets)
            val_loss += loss.item()

    avg_val_loss = val_loss / len(val_loader)

    print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
# Out:
# Train Epoch 1/15: 100%|██████████| 572/572 [00:18<00:00, 31.43it/s]
# Epoch 1/15 | Train Loss: 0.2991 | Val Loss: 0.0858
# Train Epoch 2/15: 100%|██████████| 572/572 [00:20<00:00, 28.39it/s]
# Epoch 2/15 | Train Loss: 0.1360 | Val Loss: 0.0639
# Train Epoch 3/15: 100%|██████████| 572/572 [00:19<00:00, 29.80it/s]
# Epoch 3/15 | Train Loss: 0.1039 | Val Loss: 0.0517
# Train Epoch 4/15: 100%|██████████| 572/572 [00:18<00:00, 31.01it/s]
# Epoch 4/15 | Train Loss: 0.0913 | Val Loss: 0.0446
# Train Epoch 5/15: 100%|██████████| 572/572 [00:20<00:00, 28.00it/s]
# Epoch 5/15 | Train Loss: 0.0818 | Val Loss: 0.0424
# Train Epoch 6/15: 100%|██████████| 572/572 [00:19<00:00, 28.98it/s]
# Epoch 6/15 | Train Loss: 0.0826 | Val Loss: 0.0524
# Train Epoch 7/15: 100%|██████████| 572/572 [00:21<00:00, 26.47it/s]
# Epoch 7/15 | Train Loss: 0.0673 | Val Loss: 0.0418
# Train Epoch 8/15: 100%|██████████| 572/572 [00:20<00:00, 28.04it/s]
# Epoch 8/15 | Train Loss: 0.0638 | Val Loss: 0.0389
# Train Epoch 9/15: 100%|██████████| 572/572 [00:20<00:00, 28.59it/s]
# Epoch 9/15 | Train Loss: 0.0662 | Val Loss: 0.0390
# Train Epoch 10/15: 100%|██████████| 572/572 [00:20<00:00, 28.48it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[193], line 33
#      31 val_loss = 0
#      32 with torch.no_grad():
# ---> 33     for images, targets in val_loader:
#      34         images = images.to(device)
#      35         targets = {k: v for k, v in targets.items()}
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/utils/data/dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1479, in _MultiProcessingDataLoaderIter._next_data(self)
#    1476 else:
#    1477     # no valid `self._rcvd_idx` is found (i.e., didn't break)
#    1478     if not self._persistent_workers:
# -> 1479         self._shutdown_workers()
#    1480     raise StopIteration
#    1482 # Now `self._rcvd_idx` is the batch index we want to fetch
#    1483
#    1484 # Check if the next sample has already been generated
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1627, in _MultiProcessingDataLoaderIter._shutdown_workers(self)
#    1622         self._mark_worker_as_unavailable(worker_id, shutdown=True)
#    1623 for w in self._workers:
#    1624     # We should be able to join here, but in case anything went
#    1625     # wrong, we set a timeout and if the workers fail to join,
#    1626     # they are killed in the `finally` block.
# -> 1627     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#    1628 for q in self._index_queues:
#    1629     q.cancel_join_thread()
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/multiprocessing/popen_fork.py:40, in Popen.wait(self, timeout)
#      38 if timeout is not None:
#      39     from multiprocessing.connection import wait
# ---> 40     if not wait([self.sentinel], timeout):
#      41         return None
#      42 # This shouldn't block if wait() returned successfully.
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/multiprocessing/connection.py:948, in wait(object_list, timeout)
#     945     deadline = time.monotonic() + timeout
#     947 while True:
# --> 948     ready = selector.select(timeout)
#     949     if ready:
#     950         return [key.fileobj for (key, events) in ready]
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Simple architecture

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = HandKeypointModel(architecture="simple").to(device)
criterion = HandKeypointLoss(use_visibility_loss=False)
optimizer = AdamW(model.parameters(), lr=1e-3)

num_epochs = 30

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for images, targets in tqdm(train_loader, desc=f"Train Epoch {epoch+1}/{num_epochs}"):
        images = images.to(device)
        targets = {k: v for k, v in targets.items()}
        targets['bbox'] = targets['bbox'].to(device)
        targets['keypoints'] = targets['keypoints'].to(device)

        optimizer.zero_grad()
        preds = model(images)

        loss, loss_dict = criterion(preds, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(train_loader)

    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for images, targets in val_loader:
            images = images.to(device)
            targets = {k: v for k, v in targets.items()}
            targets['bbox'] = targets['bbox'].to(device)
            targets['keypoints'] = targets['keypoints'].to(device)

            preds = model(images)
            loss, _ = criterion(preds, targets)
            val_loss += loss.item()

    avg_val_loss = val_loss / len(val_loader)

    print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
# Out:
# Train Epoch 1/30:   0%|          | 0/572 [00:00<?, ?it/s]
# Train Epoch 1/30: 100%|██████████| 572/572 [00:12<00:00, 44.82it/s]
# Epoch 1/30 | Train Loss: 0.6001 | Val Loss: 0.5210
# Train Epoch 2/30: 100%|██████████| 572/572 [00:11<00:00, 48.66it/s]
# Epoch 2/30 | Train Loss: 0.4903 | Val Loss: 0.4218
# Train Epoch 3/30: 100%|██████████| 572/572 [00:12<00:00, 45.93it/s]
# Epoch 3/30 | Train Loss: 0.4295 | Val Loss: 0.4468
# Train Epoch 4/30: 100%|██████████| 572/572 [00:12<00:00, 46.28it/s]
# Epoch 4/30 | Train Loss: 0.3742 | Val Loss: 0.3423
# Train Epoch 5/30: 100%|██████████| 572/572 [00:12<00:00, 45.24it/s]
# Epoch 5/30 | Train Loss: 0.3288 | Val Loss: 0.6166
# Train Epoch 6/30: 100%|██████████| 572/572 [00:13<00:00, 43.52it/s]
# Epoch 6/30 | Train Loss: 0.2960 | Val Loss: 0.2536
# Train Epoch 7/30: 100%|██████████| 572/572 [00:12<00:00, 44.55it/s]
# Epoch 7/30 | Train Loss: 0.2651 | Val Loss: 0.4746
# Train Epoch 8/30: 100%|██████████| 572/572 [00:12<00:00, 44.54it/s]
# Epoch 8/30 | Train Loss: 0.2430 | Val Loss: 0.2095
# Train Epoch 9/30: 100%|██████████| 572/572 [00:12<00:00, 45.80it/s]
# Epoch 9/30 | Train Loss: 0.2231 | Val Loss: 0.2625
# Train Epoch 10/30: 100%|██████████| 572/572 [00:12<00:00, 46.69it/s]
# Epoch 10/30 | Train Loss: 0.2033 | Val Loss: 0.1865
# Train Epoch 11/30: 100%|██████████| 572/572 [00:12<00:00, 44.60it/s]
# Epoch 11/30 | Train Loss: 0.1889 | Val Loss: 0.1916
# Train Epoch 12/30: 100%|██████████| 572/572 [00:12<00:00, 44.23it/s]
# Epoch 12/30 | Train Loss: 0.1759 | Val Loss: 0.1667
# Train Epoch 13/30: 100%|██████████| 572/572 [00:12<00:00, 45.98it/s]
# Epoch 13/30 | Train Loss: 0.1679 | Val Loss: 0.2070
# Train Epoch 14/30: 100%|██████████| 572/572 [00:12<00:00, 44.48it/s]
# Epoch 14/30 | Train Loss: 0.1610 | Val Loss: 0.2078
# Train Epoch 15/30: 100%|██████████| 572/572 [00:12<00:00, 45.54it/s]
# Epoch 15/30 | Train Loss: 0.1525 | Val Loss: 0.1590
# Train Epoch 16/30: 100%|██████████| 572/572 [00:12<00:00, 44.21it/s]
# Epoch 16/30 | Train Loss: 0.1446 | Val Loss: 0.1562
# Train Epoch 17/30: 100%|██████████| 572/572 [00:12<00:00, 44.47it/s]
# Epoch 17/30 | Train Loss: 0.1406 | Val Loss: 0.1541
# Train Epoch 18/30: 100%|██████████| 572/572 [00:12<00:00, 44.79it/s]
# Epoch 18/30 | Train Loss: 0.1331 | Val Loss: 0.1631
# Train Epoch 19/30: 100%|██████████| 572/572 [00:12<00:00, 46.51it/s]
# Epoch 19/30 | Train Loss: 0.1279 | Val Loss: 0.1188
# Train Epoch 20/30: 100%|██████████| 572/572 [00:12<00:00, 45.04it/s]
# Epoch 20/30 | Train Loss: 0.1255 | Val Loss: 0.1626
# Train Epoch 21/30: 100%|██████████| 572/572 [00:12<00:00, 45.17it/s]
# Epoch 21/30 | Train Loss: 0.1234 | Val Loss: 0.1621
# Train Epoch 22/30: 100%|██████████| 572/572 [00:12<00:00, 44.37it/s]
# Epoch 22/30 | Train Loss: 0.1178 | Val Loss: 0.1530
# Train Epoch 23/30: 100%|██████████| 572/572 [00:12<00:00, 45.60it/s]
# Epoch 23/30 | Train Loss: 0.1164 | Val Loss: 0.1342
# Train Epoch 24/30: 100%|██████████| 572/572 [00:12<00:00, 44.05it/s]
# Epoch 24/30 | Train Loss: 0.1098 | Val Loss: 0.0964
# Train Epoch 25/30: 100%|██████████| 572/572 [00:12<00:00, 45.92it/s]
# Epoch 25/30 | Train Loss: 0.1085 | Val Loss: 0.1456
# Train Epoch 26/30: 100%|██████████| 572/572 [00:12<00:00, 45.03it/s]
# Epoch 26/30 | Train Loss: 0.1073 | Val Loss: 0.0912
# Train Epoch 27/30: 100%|██████████| 572/572 [00:12<00:00, 45.20it/s]
# Epoch 27/30 | Train Loss: 0.1077 | Val Loss: 0.1420
# Train Epoch 28/30: 100%|██████████| 572/572 [00:12<00:00, 45.43it/s]
# Epoch 28/30 | Train Loss: 0.1017 | Val Loss: 0.1499
# Train Epoch 29/30: 100%|██████████| 572/572 [00:12<00:00, 46.83it/s]
# Epoch 29/30 | Train Loss: 0.1018 | Val Loss: 0.0891
# Train Epoch 30/30: 100%|██████████| 572/572 [00:12<00:00, 45.10it/s]
# Epoch 30/30 | Train Loss: 0.0983 | Val Loss: 0.0955

# %% [markdown]
# #### Heatmaps

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = HeatmapHandKeypointModel(architecture="resnet18", num_keypoints=21, heatmap_size=56).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)

num_epochs = 14

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for images, targets in tqdm(train_loader, desc=f"Train Epoch {epoch+1}/{num_epochs}"):
        images = images.to(device)
        heatmaps = targets['heatmaps'].to(device)  # extract heatmaps tensor

        optimizer.zero_grad()
        preds = model(images)  # preds shape: [B, 21, 64, 64]

        loss = criterion(preds, heatmaps)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(train_loader)

    # Validation loop
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for images, targets in val_loader:
            images = images.to(device)
            heatmaps = targets['heatmaps'].to(device)

            preds = model(images)
            loss = criterion(preds, heatmaps)
            val_loss += loss.item()

    avg_val_loss = val_loss / len(val_loader)

    print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
# Out:
# Train Epoch 1/14: 100%|██████████| 572/572 [00:21<00:00, 26.16it/s]
# Epoch 1/14 | Train Loss: 0.0030 | Val Loss: 0.0017
# Train Epoch 2/14: 100%|██████████| 572/572 [00:21<00:00, 26.21it/s]
# Epoch 2/14 | Train Loss: 0.0017 | Val Loss: 0.0017
# Train Epoch 3/14: 100%|██████████| 572/572 [00:21<00:00, 26.57it/s]
# Epoch 3/14 | Train Loss: 0.0016 | Val Loss: 0.0016
# Train Epoch 4/14: 100%|██████████| 572/572 [00:21<00:00, 26.85it/s]
# Epoch 4/14 | Train Loss: 0.0016 | Val Loss: 0.0016
# Train Epoch 5/14: 100%|██████████| 572/572 [00:21<00:00, 26.31it/s]
# Epoch 5/14 | Train Loss: 0.0016 | Val Loss: 0.0016
# Train Epoch 6/14: 100%|██████████| 572/572 [00:21<00:00, 26.45it/s]
# Epoch 6/14 | Train Loss: 0.0016 | Val Loss: 0.0016
# Train Epoch 7/14:  15%|█▍        | 85/572 [00:03<00:20, 23.27it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[181], line 17
#      14 heatmaps = targets['heatmaps'].to(device)  # extract heatmaps tensor
#      16 optimizer.zero_grad()
# ---> 17 preds = model(images)  # preds shape: [B, 21, 64, 64]
#      19 loss = criterion(preds, heatmaps)
#      20 loss.backward()
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# Cell In[169], line 65, in HeatmapHandKeypointModel.forward(self, x)
#      64 def forward(self, x):
# ---> 65     x = self.backbone(x)               # -> [B, C, H, W]
#      66     x = self.head(x)                   # -> [B, num_keypoints, H, W]
#      67     x = self.upsample(x)               # -> [B, num_keypoints, heatmap_size, heatmap_size]
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torchvision/models/resnet.py:96, in BasicBlock.forward(self, x)
#      93 out = self.bn1(out)
#      94 out = self.relu(out)
# ---> 96 out = self.conv2(out)
#      97 out = self.bn2(out)
#      99 if self.downsample is not None:
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniforge3/envs/cv_3d/lib/python3.11/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %% [markdown]
# ### Inference

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load and preprocess image
img_path = "datasets/hand-keypoints/val/images/IMG_00000003.jpg"
orig_img = cv2.imread(img_path)
img_rgb = cv2.cvtColor(orig_img, cv2.COLOR_BGR2RGB)

# Same transforms as in training
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])
input_tensor = transform(orig_img).unsqueeze(0)  # [1, 3, H, W]

# %% [markdown]
# #### Points and bboxes

# %%
# Inference and visualization
vis_image = predict_and_draw(model, input_tensor, orig_img)

# Now display it
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
plt.imshow(vis_image)
plt.axis("off")
plt.title("Predicted Hand Keypoints")
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# #### Heatmaps

# %%
# Inference and visualization
vis_image = predict_and_draw(model, input_tensor, orig_img, threshold=0)

plt.figure(figsize=(8, 8))
plt.imshow(vis_image)
plt.axis("off")
plt.title("Predicted Hand Keypoints")
plt.show()
